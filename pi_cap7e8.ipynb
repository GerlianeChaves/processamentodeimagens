# %% [markdown]
# <a href="https://colab.research.google.com/github/GerlianeChaves/processamentodeimagens/blob/main/pi_cap7e8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **CAPITULO 7 E 8**

# %% [markdown]
# ## CONFIGURAÇÕES

# %%
#imports 
import cv2
import numpy as np
from google.colab.patches import cv2_imshow 
import matplotlib.pyplot as plt 
import random
from skimage.color import rgb2gray

# %%
#conecta com o google drive
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).

# %% [markdown]
# ## QUESTÃO 1
# 1. Abra a imagem Fig0516(a)(applo17_boulder_noisy) e faça uma imagem filtragem no domínio da frequência retirando as altas frequências.

# %%
img = cv2.imread('/gdrive/My Drive/Colab Notebooks/ProcessamentoImagem/Fig0516(a)(applo17_boulder_noisy).tif')

cv2_imshow(img)
print('Imagem Original')
print(img.shape)
# Out:
# <PIL.Image.Image image mode=RGB size=630x474 at 0x7FE9DB1B1720>
# Imagem Original
# (474, 630, 3)

# %% [markdown]
# ## QUESTÃO 2
# 2. Abra a imagem Fig0734(a) e plot as altas e baixas frequências. Especifique o tamanho do filtro utilizado.

# %%
img = cv2.imread('/gdrive/My Drive/Colab Notebooks/ProcessamentoImagem/Fig0734(a).tif')

cv2_imshow(img)
print('Imagem Original')
print(img.shape)

img_bgr = cv2.imread('scenary.jpg', 1) 
   
color = ('b', 'g', 'r') 
  
for i, col in enumerate(color): 
    histr = cv2.calcHist([img_bgr], [i], None, [256], [0, 256]) 
    plt.plot(histr, color = col) 
    plt.xlim([0, 256]) 
      
plt.show()
# Out:
# <PIL.Image.Image image mode=RGB size=400x480 at 0x7FE9DB1B1AE0>
# Imagem Original
# (480, 400, 3)
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-5-0fedab1d4927> in <cell line: 11>()
#      10
#      11 for i, col in enumerate(color):
# ---> 12     histr = cv2.calcHist([img_bgr], [i], None, [256], [0, 256])
#      13     plt.plot(histr, color = col)
#      14     plt.xlim([0, 256])
#
# error: OpenCV(4.7.0) /io/opencv/modules/imgproc/src/histogram.cpp:160: error: (-215:Assertion failed) j < nimages in function 'histPrepareImages'

# %% [markdown]
# ## QUESTÃO 3
# 3. Adicione os seguintes ruídos à imagem Fig0503 (original_pattern):
#
# a) Gaussiano
#
# b) Rayleigh
#
# c) Gama
#
# d) Exponencial
#
# e) Uniforme
#
# f) Impusilvo

# %%
img = cv2.imread('/gdrive/My Drive/Colab Notebooks/ProcessamentoImagem/Fig0503.tif')

cv2_imshow(img)
print('Imagem Original')
print(img.shape)

#
# Out:
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7FE9A2D3C3A0>
# Imagem Original
# (256, 256, 3)
